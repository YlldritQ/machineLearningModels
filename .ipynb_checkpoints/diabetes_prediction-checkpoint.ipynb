# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    classification_report, confusion_matrix,
    accuracy_score, roc_auc_score, roc_curve
)

# Load and preprocess data
columns = ['pregnancies', 'glucose', 'blood_pressure', 'skin_thickness',
           'insulin', 'bmi', 'diabetes_pedigree', 'age', 'outcome']
data = pd.read_csv('pima-indians-diabetes.data', delimiter=',', names=columns, header=None)

# Clean invalid zeros
invalid_zero_cols = ['glucose', 'blood_pressure', 'skin_thickness', 'insulin', 'bmi']
data[invalid_zero_cols] = data[invalid_zero_cols].replace(0, np.nan)
data.fillna(data.median(numeric_only=True), inplace=True)

# Split and scale data
X = data.drop('outcome', axis=1)
y = data['outcome']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# MLP Model
model = MLPClassifier(hidden_layer_sizes=(32, 16, 8), activation='relu',
                      solver='adam', max_iter=1, warm_start=True,
                      early_stopping=False, random_state=42)

# Manual training loop
epochs = 300
train_acc, test_acc = [], []
train_loss = []
classes = np.unique(y_train)

for epoch in range(epochs):
    model.partial_fit(X_train_scaled, y_train, classes=classes)
    y_train_pred = model.predict(X_train_scaled)
    y_test_pred = model.predict(X_test_scaled)
    
    train_acc.append(accuracy_score(y_train, y_train_pred))
    test_acc.append(accuracy_score(y_test, y_test_pred))
    train_loss.append(model.loss_)
    
    print(f"Epoch {epoch+1}/{epochs} - Train Acc: {train_acc[-1]:.4f} - Test Acc: {test_acc[-1]:.4f} - Loss: {train_loss[-1]:.4f}")

# Final predictions
y_pred = model.predict(X_test_scaled)
y_prob = model.predict_proba(X_test_scaled)[:, 1]

# Classification Report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Accuracy and Loss Plot
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_acc, label="Train Accuracy")
plt.plot(test_acc, label="Test Accuracy")
plt.title("Accuracy Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_loss, label="Training Loss", color='orange')
plt.title("Training Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.tight_layout()
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_prob)
auc_score = roc_auc_score(y_test, y_prob)

plt.figure(figsize=(7, 5))
plt.plot(fpr, tpr, label=f"ROC AUC = {auc_score:.2f}")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.show()

# Predict examples
columns = ['pregnancies', 'glucose', 'blood_pressure', 'skin_thickness',
           'insulin', 'bmi', 'diabetes_pedigree', 'age']

# Fix for warning: convert NumPy arrays to DataFrames before scaling
high_risk = pd.DataFrame([[10, 180, 90, 35, 200, 40.0, 1.5, 60]], columns=columns)
low_risk = pd.DataFrame([[1, 85, 60, 20, 80, 22.0, 0.2, 25]], columns=columns)

high_risk_scaled = scaler.transform(high_risk)
low_risk_scaled = scaler.transform(low_risk)

print("\nExample Predictions:")
for i, (person_scaled, label_raw) in enumerate([(high_risk_scaled, "High Risk"), (low_risk_scaled, "Low Risk")], 1):
    pred = model.predict(person_scaled)[0]
    prob = model.predict_proba(person_scaled)[0][1]
    label = "Diabetic" if pred == 1 else "Non-Diabetic"
    print(f"{label_raw} Person: Prediction = {label} (Probability = {prob:.2%})")

# Show predictions for the last 5 entries in the test set
print("\nLast 5 Samples from Test Set with Predictions:")
last_5 = X_test.tail(5)
last_5_scaled = scaler.transform(last_5)

preds = model.predict(last_5_scaled)
probs = model.predict_proba(last_5_scaled)[:, 1]

for i, (input_vals, pred_label, prob_val) in enumerate(zip(last_5.values, preds, probs), 1):
    label = "Diabetic" if pred_label == 1 else "Non-Diabetic"
    print(f"Sample {i}: Features = {input_vals} -> Prediction = {label} (Probability = {prob_val:.2%})")
# Out:
# Epoch 1/300 - Train Acc: 0.6499 - Test Acc: 0.6537 - Loss: 0.6505
# Epoch 2/300 - Train Acc: 0.6499 - Test Acc: 0.6494 - Loss: 0.6392
# Epoch 3/300 - Train Acc: 0.6499 - Test Acc: 0.6494 - Loss: 0.6298
# Epoch 4/300 - Train Acc: 0.6499 - Test Acc: 0.6494 - Loss: 0.6216
# Epoch 5/300 - Train Acc: 0.6499 - Test Acc: 0.6537 - Loss: 0.6141
# Epoch 6/300 - Train Acc: 0.6518 - Test Acc: 0.6580 - Loss: 0.6068
# Epoch 7/300 - Train Acc: 0.6536 - Test Acc: 0.6537 - Loss: 0.5994
# Epoch 8/300 - Train Acc: 0.6592 - Test Acc: 0.6537 - Loss: 0.5918
# Epoch 9/300 - Train Acc: 0.6704 - Test Acc: 0.6494 - Loss: 0.5841
# Epoch 10/300 - Train Acc: 0.6723 - Test Acc: 0.6537 - Loss: 0.5754
# Epoch 11/300 - Train Acc: 0.6723 - Test Acc: 0.6667 - Loss: 0.5661
# Epoch 12/300 - Train Acc: 0.6778 - Test Acc: 0.6753 - Loss: 0.5565
# Epoch 13/300 - Train Acc: 0.7020 - Test Acc: 0.6753 - Loss: 0.5465
# Epoch 14/300 - Train Acc: 0.7188 - Test Acc: 0.7013 - Loss: 0.5362
# Epoch 15/300 - Train Acc: 0.7281 - Test Acc: 0.7186 - Loss: 0.5259
# Epoch 16/300 - Train Acc: 0.7393 - Test Acc: 0.7619 - Loss: 0.5162
# Epoch 17/300 - Train Acc: 0.7579 - Test Acc: 0.7576 - Loss: 0.5071
# Epoch 18/300 - Train Acc: 0.7691 - Test Acc: 0.7532 - Loss: 0.4990
# Epoch 19/300 - Train Acc: 0.7728 - Test Acc: 0.7446 - Loss: 0.4917
# Epoch 20/300 - Train Acc: 0.7635 - Test Acc: 0.7359 - Loss: 0.4853
# Epoch 21/300 - Train Acc: 0.7635 - Test Acc: 0.7316 - Loss: 0.4795
# Epoch 22/300 - Train Acc: 0.7672 - Test Acc: 0.7359 - Loss: 0.4743
# Epoch 23/300 - Train Acc: 0.7691 - Test Acc: 0.7446 - Loss: 0.4696
# Epoch 24/300 - Train Acc: 0.7691 - Test Acc: 0.7532 - Loss: 0.4652
# Epoch 25/300 - Train Acc: 0.7709 - Test Acc: 0.7576 - Loss: 0.4612
# Epoch 26/300 - Train Acc: 0.7747 - Test Acc: 0.7576 - Loss: 0.4576
# Epoch 27/300 - Train Acc: 0.7747 - Test Acc: 0.7532 - Loss: 0.4543
# Epoch 28/300 - Train Acc: 0.7765 - Test Acc: 0.7446 - Loss: 0.4512
# Epoch 29/300 - Train Acc: 0.7784 - Test Acc: 0.7446 - Loss: 0.4483
# Epoch 30/300 - Train Acc: 0.7784 - Test Acc: 0.7489 - Loss: 0.4456
# Epoch 31/300 - Train Acc: 0.7765 - Test Acc: 0.7446 - Loss: 0.4431
# Epoch 32/300 - Train Acc: 0.7747 - Test Acc: 0.7403 - Loss: 0.4407
# Epoch 33/300 - Train Acc: 0.7803 - Test Acc: 0.7359 - Loss: 0.4383
# Epoch 34/300 - Train Acc: 0.7803 - Test Acc: 0.7359 - Loss: 0.4361
# Epoch 35/300 - Train Acc: 0.7858 - Test Acc: 0.7403 - Loss: 0.4341
# Epoch 36/300 - Train Acc: 0.7858 - Test Acc: 0.7403 - Loss: 0.4321
# Epoch 37/300 - Train Acc: 0.7840 - Test Acc: 0.7446 - Loss: 0.4302
# Epoch 38/300 - Train Acc: 0.7840 - Test Acc: 0.7446 - Loss: 0.4285
# Epoch 39/300 - Train Acc: 0.7821 - Test Acc: 0.7446 - Loss: 0.4268
# Epoch 40/300 - Train Acc: 0.7821 - Test Acc: 0.7446 - Loss: 0.4252
# Epoch 41/300 - Train Acc: 0.7858 - Test Acc: 0.7446 - Loss: 0.4236
# Epoch 42/300 - Train Acc: 0.7877 - Test Acc: 0.7446 - Loss: 0.4220
# Epoch 43/300 - Train Acc: 0.7877 - Test Acc: 0.7489 - Loss: 0.4205
# Epoch 44/300 - Train Acc: 0.7877 - Test Acc: 0.7489 - Loss: 0.4191
# Epoch 45/300 - Train Acc: 0.7877 - Test Acc: 0.7489 - Loss: 0.4176
# Epoch 46/300 - Train Acc: 0.7877 - Test Acc: 0.7489 - Loss: 0.4163
# Epoch 47/300 - Train Acc: 0.7896 - Test Acc: 0.7489 - Loss: 0.4149
# Epoch 48/300 - Train Acc: 0.7877 - Test Acc: 0.7489 - Loss: 0.4136
# Epoch 49/300 - Train Acc: 0.7877 - Test Acc: 0.7489 - Loss: 0.4124
# Epoch 50/300 - Train Acc: 0.7933 - Test Acc: 0.7489 - Loss: 0.4112
# Epoch 51/300 - Train Acc: 0.7933 - Test Acc: 0.7489 - Loss: 0.4100
# Epoch 52/300 - Train Acc: 0.7896 - Test Acc: 0.7532 - Loss: 0.4088
# Epoch 53/300 - Train Acc: 0.7914 - Test Acc: 0.7532 - Loss: 0.4077
# Epoch 54/300 - Train Acc: 0.7914 - Test Acc: 0.7532 - Loss: 0.4066
# Epoch 55/300 - Train Acc: 0.7933 - Test Acc: 0.7532 - Loss: 0.4055
# Epoch 56/300 - Train Acc: 0.7970 - Test Acc: 0.7576 - Loss: 0.4044
# Epoch 57/300 - Train Acc: 0.7989 - Test Acc: 0.7532 - Loss: 0.4033
# Epoch 58/300 - Train Acc: 0.7989 - Test Acc: 0.7576 - Loss: 0.4022
# Epoch 59/300 - Train Acc: 0.8007 - Test Acc: 0.7576 - Loss: 0.4011
# Epoch 60/300 - Train Acc: 0.8007 - Test Acc: 0.7489 - Loss: 0.4000
# Epoch 61/300 - Train Acc: 0.8026 - Test Acc: 0.7489 - Loss: 0.3990
# Epoch 62/300 - Train Acc: 0.8045 - Test Acc: 0.7489 - Loss: 0.3980
# Epoch 63/300 - Train Acc: 0.8026 - Test Acc: 0.7489 - Loss: 0.3970
# Epoch 64/300 - Train Acc: 0.8026 - Test Acc: 0.7532 - Loss: 0.3960
# Epoch 65/300 - Train Acc: 0.8026 - Test Acc: 0.7532 - Loss: 0.3951
# Epoch 66/300 - Train Acc: 0.8026 - Test Acc: 0.7532 - Loss: 0.3941
# Epoch 67/300 - Train Acc: 0.8007 - Test Acc: 0.7532 - Loss: 0.3932
# Epoch 68/300 - Train Acc: 0.8045 - Test Acc: 0.7532 - Loss: 0.3922
# Epoch 69/300 - Train Acc: 0.8045 - Test Acc: 0.7576 - Loss: 0.3912
# Epoch 70/300 - Train Acc: 0.8045 - Test Acc: 0.7576 - Loss: 0.3902
# Epoch 71/300 - Train Acc: 0.8082 - Test Acc: 0.7576 - Loss: 0.3892
# Epoch 72/300 - Train Acc: 0.8082 - Test Acc: 0.7576 - Loss: 0.3882
# Epoch 73/300 - Train Acc: 0.8063 - Test Acc: 0.7576 - Loss: 0.3872
# Epoch 74/300 - Train Acc: 0.8063 - Test Acc: 0.7576 - Loss: 0.3861
# Epoch 75/300 - Train Acc: 0.8082 - Test Acc: 0.7576 - Loss: 0.3851
# Epoch 76/300 - Train Acc: 0.8063 - Test Acc: 0.7532 - Loss: 0.3841
# Epoch 77/300 - Train Acc: 0.8082 - Test Acc: 0.7532 - Loss: 0.3830
# Epoch 78/300 - Train Acc: 0.8082 - Test Acc: 0.7576 - Loss: 0.3820
# Epoch 79/300 - Train Acc: 0.8101 - Test Acc: 0.7576 - Loss: 0.3811
# Epoch 80/300 - Train Acc: 0.8082 - Test Acc: 0.7576 - Loss: 0.3801
# Epoch 81/300 - Train Acc: 0.8101 - Test Acc: 0.7576 - Loss: 0.3791
# Epoch 82/300 - Train Acc: 0.8119 - Test Acc: 0.7619 - Loss: 0.3781
# Epoch 83/300 - Train Acc: 0.8082 - Test Acc: 0.7662 - Loss: 0.3771
# Epoch 84/300 - Train Acc: 0.8082 - Test Acc: 0.7619 - Loss: 0.3761
# Epoch 85/300 - Train Acc: 0.8082 - Test Acc: 0.7619 - Loss: 0.3752
# Epoch 86/300 - Train Acc: 0.8138 - Test Acc: 0.7576 - Loss: 0.3742
# Epoch 87/300 - Train Acc: 0.8156 - Test Acc: 0.7576 - Loss: 0.3732
# Epoch 88/300 - Train Acc: 0.8194 - Test Acc: 0.7532 - Loss: 0.3723
# Epoch 89/300 - Train Acc: 0.8175 - Test Acc: 0.7489 - Loss: 0.3713
# Epoch 90/300 - Train Acc: 0.8138 - Test Acc: 0.7532 - Loss: 0.3703
# Epoch 91/300 - Train Acc: 0.8138 - Test Acc: 0.7446 - Loss: 0.3694
# Epoch 92/300 - Train Acc: 0.8138 - Test Acc: 0.7403 - Loss: 0.3684
# Epoch 93/300 - Train Acc: 0.8194 - Test Acc: 0.7403 - Loss: 0.3675
# Epoch 94/300 - Train Acc: 0.8212 - Test Acc: 0.7446 - Loss: 0.3665
# Epoch 95/300 - Train Acc: 0.8231 - Test Acc: 0.7446 - Loss: 0.3655
# Epoch 96/300 - Train Acc: 0.8250 - Test Acc: 0.7403 - Loss: 0.3646
# Epoch 97/300 - Train Acc: 0.8250 - Test Acc: 0.7446 - Loss: 0.3636
# Epoch 98/300 - Train Acc: 0.8250 - Test Acc: 0.7446 - Loss: 0.3626
# Epoch 99/300 - Train Acc: 0.8250 - Test Acc: 0.7489 - Loss: 0.3616
# Epoch 100/300 - Train Acc: 0.8250 - Test Acc: 0.7489 - Loss: 0.3606
# Epoch 101/300 - Train Acc: 0.8287 - Test Acc: 0.7489 - Loss: 0.3596
# Epoch 102/300 - Train Acc: 0.8287 - Test Acc: 0.7489 - Loss: 0.3586
# Epoch 103/300 - Train Acc: 0.8268 - Test Acc: 0.7489 - Loss: 0.3575
# Epoch 104/300 - Train Acc: 0.8287 - Test Acc: 0.7489 - Loss: 0.3565
# Epoch 105/300 - Train Acc: 0.8343 - Test Acc: 0.7446 - Loss: 0.3555
# Epoch 106/300 - Train Acc: 0.8361 - Test Acc: 0.7446 - Loss: 0.3544
# Epoch 107/300 - Train Acc: 0.8343 - Test Acc: 0.7446 - Loss: 0.3534
# Epoch 108/300 - Train Acc: 0.8380 - Test Acc: 0.7446 - Loss: 0.3523
# Epoch 109/300 - Train Acc: 0.8361 - Test Acc: 0.7446 - Loss: 0.3512
# Epoch 110/300 - Train Acc: 0.8380 - Test Acc: 0.7489 - Loss: 0.3501
# Epoch 111/300 - Train Acc: 0.8399 - Test Acc: 0.7489 - Loss: 0.3491
# Epoch 112/300 - Train Acc: 0.8399 - Test Acc: 0.7489 - Loss: 0.3480
# Epoch 113/300 - Train Acc: 0.8399 - Test Acc: 0.7489 - Loss: 0.3469
# Epoch 114/300 - Train Acc: 0.8417 - Test Acc: 0.7532 - Loss: 0.3458
# Epoch 115/300 - Train Acc: 0.8417 - Test Acc: 0.7532 - Loss: 0.3447
# Epoch 116/300 - Train Acc: 0.8417 - Test Acc: 0.7532 - Loss: 0.3436
# Epoch 117/300 - Train Acc: 0.8399 - Test Acc: 0.7489 - Loss: 0.3425
# Epoch 118/300 - Train Acc: 0.8417 - Test Acc: 0.7446 - Loss: 0.3414
# Epoch 119/300 - Train Acc: 0.8417 - Test Acc: 0.7403 - Loss: 0.3403
# Epoch 120/300 - Train Acc: 0.8436 - Test Acc: 0.7403 - Loss: 0.3392
# Epoch 121/300 - Train Acc: 0.8454 - Test Acc: 0.7403 - Loss: 0.3381
# Epoch 122/300 - Train Acc: 0.8454 - Test Acc: 0.7403 - Loss: 0.3371
# Epoch 123/300 - Train Acc: 0.8492 - Test Acc: 0.7403 - Loss: 0.3360
# Epoch 124/300 - Train Acc: 0.8473 - Test Acc: 0.7403 - Loss: 0.3349
# Epoch 125/300 - Train Acc: 0.8492 - Test Acc: 0.7403 - Loss: 0.3339
# Epoch 126/300 - Train Acc: 0.8492 - Test Acc: 0.7403 - Loss: 0.3328
# Epoch 127/300 - Train Acc: 0.8492 - Test Acc: 0.7403 - Loss: 0.3317
# Epoch 128/300 - Train Acc: 0.8473 - Test Acc: 0.7403 - Loss: 0.3306
# Epoch 129/300 - Train Acc: 0.8473 - Test Acc: 0.7403 - Loss: 0.3295
# Epoch 130/300 - Train Acc: 0.8510 - Test Acc: 0.7359 - Loss: 0.3285
# Epoch 131/300 - Train Acc: 0.8529 - Test Acc: 0.7359 - Loss: 0.3274
# Epoch 132/300 - Train Acc: 0.8529 - Test Acc: 0.7359 - Loss: 0.3262
# Epoch 133/300 - Train Acc: 0.8547 - Test Acc: 0.7316 - Loss: 0.3251
# Epoch 134/300 - Train Acc: 0.8547 - Test Acc: 0.7273 - Loss: 0.3239
# Epoch 135/300 - Train Acc: 0.8566 - Test Acc: 0.7316 - Loss: 0.3228
# Epoch 136/300 - Train Acc: 0.8566 - Test Acc: 0.7316 - Loss: 0.3216
# Epoch 137/300 - Train Acc: 0.8603 - Test Acc: 0.7316 - Loss: 0.3204
# Epoch 138/300 - Train Acc: 0.8622 - Test Acc: 0.7316 - Loss: 0.3192
# Epoch 139/300 - Train Acc: 0.8603 - Test Acc: 0.7316 - Loss: 0.3180
# Epoch 140/300 - Train Acc: 0.8603 - Test Acc: 0.7316 - Loss: 0.3169
# Epoch 141/300 - Train Acc: 0.8641 - Test Acc: 0.7359 - Loss: 0.3157
# Epoch 142/300 - Train Acc: 0.8622 - Test Acc: 0.7359 - Loss: 0.3145
# Epoch 143/300 - Train Acc: 0.8641 - Test Acc: 0.7359 - Loss: 0.3133
# Epoch 144/300 - Train Acc: 0.8603 - Test Acc: 0.7403 - Loss: 0.3122
# Epoch 145/300 - Train Acc: 0.8603 - Test Acc: 0.7403 - Loss: 0.3110
# Epoch 146/300 - Train Acc: 0.8622 - Test Acc: 0.7403 - Loss: 0.3099
# Epoch 147/300 - Train Acc: 0.8622 - Test Acc: 0.7403 - Loss: 0.3087
# Epoch 148/300 - Train Acc: 0.8622 - Test Acc: 0.7446 - Loss: 0.3075
# Epoch 149/300 - Train Acc: 0.8641 - Test Acc: 0.7446 - Loss: 0.3063
# Epoch 150/300 - Train Acc: 0.8641 - Test Acc: 0.7489 - Loss: 0.3051
# Epoch 151/300 - Train Acc: 0.8641 - Test Acc: 0.7489 - Loss: 0.3039
# Epoch 152/300 - Train Acc: 0.8659 - Test Acc: 0.7489 - Loss: 0.3027
# Epoch 153/300 - Train Acc: 0.8696 - Test Acc: 0.7489 - Loss: 0.3015
# Epoch 154/300 - Train Acc: 0.8696 - Test Acc: 0.7489 - Loss: 0.3003
# Epoch 155/300 - Train Acc: 0.8696 - Test Acc: 0.7489 - Loss: 0.2990
# Epoch 156/300 - Train Acc: 0.8734 - Test Acc: 0.7489 - Loss: 0.2978
# Epoch 157/300 - Train Acc: 0.8734 - Test Acc: 0.7489 - Loss: 0.2965
# Epoch 158/300 - Train Acc: 0.8752 - Test Acc: 0.7489 - Loss: 0.2953
# Epoch 159/300 - Train Acc: 0.8752 - Test Acc: 0.7489 - Loss: 0.2940
# Epoch 160/300 - Train Acc: 0.8752 - Test Acc: 0.7489 - Loss: 0.2928
# Epoch 161/300 - Train Acc: 0.8752 - Test Acc: 0.7532 - Loss: 0.2916
# Epoch 162/300 - Train Acc: 0.8752 - Test Acc: 0.7532 - Loss: 0.2903
# Epoch 163/300 - Train Acc: 0.8752 - Test Acc: 0.7532 - Loss: 0.2891
# Epoch 164/300 - Train Acc: 0.8752 - Test Acc: 0.7532 - Loss: 0.2879
# Epoch 165/300 - Train Acc: 0.8771 - Test Acc: 0.7532 - Loss: 0.2865
# Epoch 166/300 - Train Acc: 0.8771 - Test Acc: 0.7489 - Loss: 0.2853
# Epoch 167/300 - Train Acc: 0.8790 - Test Acc: 0.7489 - Loss: 0.2841
# Epoch 168/300 - Train Acc: 0.8790 - Test Acc: 0.7489 - Loss: 0.2829
# Epoch 169/300 - Train Acc: 0.8808 - Test Acc: 0.7489 - Loss: 0.2817
# Epoch 170/300 - Train Acc: 0.8790 - Test Acc: 0.7489 - Loss: 0.2805
# Epoch 171/300 - Train Acc: 0.8790 - Test Acc: 0.7489 - Loss: 0.2793
# Epoch 172/300 - Train Acc: 0.8790 - Test Acc: 0.7489 - Loss: 0.2781
# Epoch 173/300 - Train Acc: 0.8790 - Test Acc: 0.7489 - Loss: 0.2771
# Epoch 174/300 - Train Acc: 0.8808 - Test Acc: 0.7489 - Loss: 0.2759
# Epoch 175/300 - Train Acc: 0.8808 - Test Acc: 0.7489 - Loss: 0.2746
# Epoch 176/300 - Train Acc: 0.8827 - Test Acc: 0.7489 - Loss: 0.2734
# Epoch 177/300 - Train Acc: 0.8845 - Test Acc: 0.7489 - Loss: 0.2722
# Epoch 178/300 - Train Acc: 0.8845 - Test Acc: 0.7489 - Loss: 0.2710
# Epoch 179/300 - Train Acc: 0.8883 - Test Acc: 0.7446 - Loss: 0.2697
# Epoch 180/300 - Train Acc: 0.8883 - Test Acc: 0.7446 - Loss: 0.2685
# Epoch 181/300 - Train Acc: 0.8901 - Test Acc: 0.7489 - Loss: 0.2672
# Epoch 182/300 - Train Acc: 0.8920 - Test Acc: 0.7489 - Loss: 0.2659
# Epoch 183/300 - Train Acc: 0.8920 - Test Acc: 0.7489 - Loss: 0.2647
# Epoch 184/300 - Train Acc: 0.8939 - Test Acc: 0.7489 - Loss: 0.2633
# Epoch 185/300 - Train Acc: 0.8939 - Test Acc: 0.7489 - Loss: 0.2621
# Epoch 186/300 - Train Acc: 0.8939 - Test Acc: 0.7489 - Loss: 0.2609
# Epoch 187/300 - Train Acc: 0.8939 - Test Acc: 0.7489 - Loss: 0.2597
# Epoch 188/300 - Train Acc: 0.8939 - Test Acc: 0.7489 - Loss: 0.2585
# Epoch 189/300 - Train Acc: 0.8957 - Test Acc: 0.7489 - Loss: 0.2572
# Epoch 190/300 - Train Acc: 0.8957 - Test Acc: 0.7489 - Loss: 0.2560
# Epoch 191/300 - Train Acc: 0.8957 - Test Acc: 0.7489 - Loss: 0.2548
# Epoch 192/300 - Train Acc: 0.8976 - Test Acc: 0.7532 - Loss: 0.2535
# Epoch 193/300 - Train Acc: 0.8994 - Test Acc: 0.7532 - Loss: 0.2522
# Epoch 194/300 - Train Acc: 0.8976 - Test Acc: 0.7532 - Loss: 0.2510
# Epoch 195/300 - Train Acc: 0.8976 - Test Acc: 0.7532 - Loss: 0.2498
# Epoch 196/300 - Train Acc: 0.8957 - Test Acc: 0.7532 - Loss: 0.2485
# Epoch 197/300 - Train Acc: 0.8957 - Test Acc: 0.7532 - Loss: 0.2474
# Epoch 198/300 - Train Acc: 0.8957 - Test Acc: 0.7532 - Loss: 0.2462
# Epoch 199/300 - Train Acc: 0.8957 - Test Acc: 0.7532 - Loss: 0.2449
# Epoch 200/300 - Train Acc: 0.8957 - Test Acc: 0.7532 - Loss: 0.2438
# Epoch 201/300 - Train Acc: 0.8957 - Test Acc: 0.7532 - Loss: 0.2427
# Epoch 202/300 - Train Acc: 0.8957 - Test Acc: 0.7532 - Loss: 0.2415
# Epoch 203/300 - Train Acc: 0.8976 - Test Acc: 0.7532 - Loss: 0.2404
# Epoch 204/300 - Train Acc: 0.8976 - Test Acc: 0.7532 - Loss: 0.2393
# Epoch 205/300 - Train Acc: 0.8957 - Test Acc: 0.7532 - Loss: 0.2381
# Epoch 206/300 - Train Acc: 0.8976 - Test Acc: 0.7489 - Loss: 0.2369
# Epoch 207/300 - Train Acc: 0.9013 - Test Acc: 0.7446 - Loss: 0.2359
# Epoch 208/300 - Train Acc: 0.9032 - Test Acc: 0.7446 - Loss: 0.2348
# Epoch 209/300 - Train Acc: 0.9032 - Test Acc: 0.7403 - Loss: 0.2335
# Epoch 210/300 - Train Acc: 0.9032 - Test Acc: 0.7403 - Loss: 0.2324
# Epoch 211/300 - Train Acc: 0.9050 - Test Acc: 0.7446 - Loss: 0.2312
# Epoch 212/300 - Train Acc: 0.9050 - Test Acc: 0.7489 - Loss: 0.2301
# Epoch 213/300 - Train Acc: 0.9050 - Test Acc: 0.7446 - Loss: 0.2290
# Epoch 214/300 - Train Acc: 0.9050 - Test Acc: 0.7489 - Loss: 0.2277
# Epoch 215/300 - Train Acc: 0.9050 - Test Acc: 0.7489 - Loss: 0.2265
# Epoch 216/300 - Train Acc: 0.9050 - Test Acc: 0.7489 - Loss: 0.2253
# Epoch 217/300 - Train Acc: 0.9069 - Test Acc: 0.7489 - Loss: 0.2241
# Epoch 218/300 - Train Acc: 0.9069 - Test Acc: 0.7446 - Loss: 0.2230
# Epoch 219/300 - Train Acc: 0.9069 - Test Acc: 0.7446 - Loss: 0.2218
# Epoch 220/300 - Train Acc: 0.9069 - Test Acc: 0.7489 - Loss: 0.2207
# Epoch 221/300 - Train Acc: 0.9069 - Test Acc: 0.7489 - Loss: 0.2195
# Epoch 222/300 - Train Acc: 0.9088 - Test Acc: 0.7446 - Loss: 0.2185
# Epoch 223/300 - Train Acc: 0.9088 - Test Acc: 0.7532 - Loss: 0.2173
# Epoch 224/300 - Train Acc: 0.9106 - Test Acc: 0.7532 - Loss: 0.2162
# Epoch 225/300 - Train Acc: 0.9106 - Test Acc: 0.7489 - Loss: 0.2151
# Epoch 226/300 - Train Acc: 0.9125 - Test Acc: 0.7532 - Loss: 0.2140
# Epoch 227/300 - Train Acc: 0.9125 - Test Acc: 0.7532 - Loss: 0.2129
# Epoch 228/300 - Train Acc: 0.9125 - Test Acc: 0.7532 - Loss: 0.2118
# Epoch 229/300 - Train Acc: 0.9125 - Test Acc: 0.7576 - Loss: 0.2107
# Epoch 230/300 - Train Acc: 0.9125 - Test Acc: 0.7576 - Loss: 0.2096
# Epoch 231/300 - Train Acc: 0.9106 - Test Acc: 0.7576 - Loss: 0.2085
# Epoch 232/300 - Train Acc: 0.9125 - Test Acc: 0.7576 - Loss: 0.2075
# Epoch 233/300 - Train Acc: 0.9125 - Test Acc: 0.7576 - Loss: 0.2064
# Epoch 234/300 - Train Acc: 0.9125 - Test Acc: 0.7576 - Loss: 0.2053
# Epoch 235/300 - Train Acc: 0.9125 - Test Acc: 0.7576 - Loss: 0.2042
# Epoch 236/300 - Train Acc: 0.9143 - Test Acc: 0.7576 - Loss: 0.2032
# Epoch 237/300 - Train Acc: 0.9162 - Test Acc: 0.7576 - Loss: 0.2022
# Epoch 238/300 - Train Acc: 0.9162 - Test Acc: 0.7576 - Loss: 0.2010
# Epoch 239/300 - Train Acc: 0.9162 - Test Acc: 0.7532 - Loss: 0.1999
# Epoch 240/300 - Train Acc: 0.9162 - Test Acc: 0.7532 - Loss: 0.1989
# Epoch 241/300 - Train Acc: 0.9162 - Test Acc: 0.7532 - Loss: 0.1979
# Epoch 242/300 - Train Acc: 0.9162 - Test Acc: 0.7489 - Loss: 0.1968
# Epoch 243/300 - Train Acc: 0.9199 - Test Acc: 0.7532 - Loss: 0.1958
# Epoch 244/300 - Train Acc: 0.9199 - Test Acc: 0.7532 - Loss: 0.1948
# Epoch 245/300 - Train Acc: 0.9236 - Test Acc: 0.7489 - Loss: 0.1937
# Epoch 246/300 - Train Acc: 0.9236 - Test Acc: 0.7532 - Loss: 0.1928
# Epoch 247/300 - Train Acc: 0.9255 - Test Acc: 0.7576 - Loss: 0.1918
# Epoch 248/300 - Train Acc: 0.9255 - Test Acc: 0.7576 - Loss: 0.1908
# Epoch 249/300 - Train Acc: 0.9255 - Test Acc: 0.7576 - Loss: 0.1898
# Epoch 250/300 - Train Acc: 0.9292 - Test Acc: 0.7619 - Loss: 0.1888
# Epoch 251/300 - Train Acc: 0.9292 - Test Acc: 0.7619 - Loss: 0.1878
# Epoch 252/300 - Train Acc: 0.9311 - Test Acc: 0.7619 - Loss: 0.1869
# Epoch 253/300 - Train Acc: 0.9330 - Test Acc: 0.7619 - Loss: 0.1859
# Epoch 254/300 - Train Acc: 0.9330 - Test Acc: 0.7619 - Loss: 0.1848
# Epoch 255/300 - Train Acc: 0.9330 - Test Acc: 0.7619 - Loss: 0.1839
# Epoch 256/300 - Train Acc: 0.9330 - Test Acc: 0.7619 - Loss: 0.1830
# Epoch 257/300 - Train Acc: 0.9330 - Test Acc: 0.7619 - Loss: 0.1820
# Epoch 258/300 - Train Acc: 0.9330 - Test Acc: 0.7619 - Loss: 0.1811
# Epoch 259/300 - Train Acc: 0.9330 - Test Acc: 0.7576 - Loss: 0.1801
# Epoch 260/300 - Train Acc: 0.9330 - Test Acc: 0.7576 - Loss: 0.1791
# Epoch 261/300 - Train Acc: 0.9330 - Test Acc: 0.7619 - Loss: 0.1784
# Epoch 262/300 - Train Acc: 0.9330 - Test Acc: 0.7619 - Loss: 0.1774
# Epoch 263/300 - Train Acc: 0.9330 - Test Acc: 0.7619 - Loss: 0.1765
# Epoch 264/300 - Train Acc: 0.9348 - Test Acc: 0.7619 - Loss: 0.1756
# Epoch 265/300 - Train Acc: 0.9348 - Test Acc: 0.7619 - Loss: 0.1746
# Epoch 266/300 - Train Acc: 0.9348 - Test Acc: 0.7662 - Loss: 0.1738
# Epoch 267/300 - Train Acc: 0.9348 - Test Acc: 0.7662 - Loss: 0.1729
# Epoch 268/300 - Train Acc: 0.9367 - Test Acc: 0.7662 - Loss: 0.1720
# Epoch 269/300 - Train Acc: 0.9367 - Test Acc: 0.7662 - Loss: 0.1713
# Epoch 270/300 - Train Acc: 0.9367 - Test Acc: 0.7662 - Loss: 0.1702
# Epoch 271/300 - Train Acc: 0.9367 - Test Acc: 0.7706 - Loss: 0.1693
# Epoch 272/300 - Train Acc: 0.9385 - Test Acc: 0.7662 - Loss: 0.1686
# Epoch 273/300 - Train Acc: 0.9367 - Test Acc: 0.7662 - Loss: 0.1676
# Epoch 274/300 - Train Acc: 0.9385 - Test Acc: 0.7662 - Loss: 0.1668
# Epoch 275/300 - Train Acc: 0.9385 - Test Acc: 0.7662 - Loss: 0.1658
# Epoch 276/300 - Train Acc: 0.9385 - Test Acc: 0.7662 - Loss: 0.1649
# Epoch 277/300 - Train Acc: 0.9385 - Test Acc: 0.7662 - Loss: 0.1642
# Epoch 278/300 - Train Acc: 0.9385 - Test Acc: 0.7662 - Loss: 0.1631
# Epoch 279/300 - Train Acc: 0.9385 - Test Acc: 0.7662 - Loss: 0.1624
# Epoch 280/300 - Train Acc: 0.9385 - Test Acc: 0.7619 - Loss: 0.1614
# Epoch 281/300 - Train Acc: 0.9404 - Test Acc: 0.7619 - Loss: 0.1606
# Epoch 282/300 - Train Acc: 0.9404 - Test Acc: 0.7619 - Loss: 0.1598
# Epoch 283/300 - Train Acc: 0.9404 - Test Acc: 0.7619 - Loss: 0.1588
# Epoch 284/300 - Train Acc: 0.9404 - Test Acc: 0.7576 - Loss: 0.1581
# Epoch 285/300 - Train Acc: 0.9404 - Test Acc: 0.7662 - Loss: 0.1572
# Epoch 286/300 - Train Acc: 0.9423 - Test Acc: 0.7576 - Loss: 0.1563
# Epoch 287/300 - Train Acc: 0.9423 - Test Acc: 0.7619 - Loss: 0.1555
# Epoch 288/300 - Train Acc: 0.9423 - Test Acc: 0.7532 - Loss: 0.1545
# Epoch 289/300 - Train Acc: 0.9441 - Test Acc: 0.7532 - Loss: 0.1537
# Epoch 290/300 - Train Acc: 0.9441 - Test Acc: 0.7576 - Loss: 0.1529
# Epoch 291/300 - Train Acc: 0.9460 - Test Acc: 0.7532 - Loss: 0.1520
# Epoch 292/300 - Train Acc: 0.9441 - Test Acc: 0.7532 - Loss: 0.1512
# Epoch 293/300 - Train Acc: 0.9441 - Test Acc: 0.7532 - Loss: 0.1502
# Epoch 294/300 - Train Acc: 0.9479 - Test Acc: 0.7532 - Loss: 0.1493
# Epoch 295/300 - Train Acc: 0.9460 - Test Acc: 0.7576 - Loss: 0.1486
# Epoch 296/300 - Train Acc: 0.9479 - Test Acc: 0.7576 - Loss: 0.1476
# Epoch 297/300 - Train Acc: 0.9516 - Test Acc: 0.7532 - Loss: 0.1468
# Epoch 298/300 - Train Acc: 0.9460 - Test Acc: 0.7576 - Loss: 0.1460
# Epoch 299/300 - Train Acc: 0.9460 - Test Acc: 0.7576 - Loss: 0.1451
# Epoch 300/300 - Train Acc: 0.9516 - Test Acc: 0.7489 - Loss: 0.1442
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81       151
#            1       0.66      0.57      0.61        80
#
#     accuracy                           0.75       231
#    macro avg       0.72      0.71      0.71       231
# weighted avg       0.74      0.75      0.74       231
# Example Predictions:
# High Risk Person: Prediction = Non-Diabetic (Probability = 36.27%)
# Low Risk Person: Prediction = Non-Diabetic (Probability = 0.00%)
#
# Last 5 Samples from Test Set with Predictions:
# Sample 1: Features = [  0.    119.     72.     29.    125.     32.4     0.141  24.   ] -> Prediction = Diabetic (Probability = 64.73%)
# Sample 2: Features = [  4.    109.     64.     44.     99.     34.8     0.905  26.   ] -> Prediction = Non-Diabetic (Probability = 15.98%)
# Sample 3: Features = [  0.    127.     80.     37.    210.     36.3     0.804  23.   ] -> Prediction = Non-Diabetic (Probability = 18.66%)
# Sample 4: Features = [  6.    105.     70.     32.     68.     30.8     0.122  37.   ] -> Prediction = Non-Diabetic (Probability = 26.70%)
# Sample 5: Features = [ 5.    77.    82.    41.    42.    35.8    0.156 35.   ] -> Prediction = Non-Diabetic (Probability = 0.01%)

# %%
def get_user_input_and_predict(model, scaler):
    print("\n🔢 Enter patient information to predict diabetes:")
    try:
        user_data = {
            'pregnancies': int(input("Pregnancies: ")),
            'glucose': float(input("Glucose level (mg/dL): ")),
            'blood_pressure': float(input("Blood Pressure (mm Hg): ")),
            'skin_thickness': float(input("Skin Thickness (mm): ")),
            'insulin': float(input("Insulin (mu U/ml): ")),
            'bmi': float(input("BMI (kg/m²): ")),
            'diabetes_pedigree': float(input("Diabetes Pedigree Function: ")),
            'age': int(input("Age (years): "))
        }

        # Convert to DataFrame and scale
        input_df = pd.DataFrame([user_data])
        input_scaled = scaler.transform(input_df)

        # Predict
        pred = model.predict(input_scaled)[0]
        prob = model.predict_proba(input_scaled)[0][1]
        label = "Diabetic" if pred == 1 else "Non-Diabetic"

        print(f"\n📊 Prediction: {label} (Probability = {prob:.2%})")

    except ValueError:
        print("⚠️ Invalid input. Please enter numbers only.")

# Call this after training and evaluation
get_user_input_and_predict(model, scaler)
# Out:
# 🔢 Enter patient information to predict diabetes:
# Pregnancies:  0
# Glucose level (mg/dL):  130
# Blood Pressure (mm Hg):  110
# Skin Thickness (mm):  3.5
# Insulin (mu U/ml):  120
# BMI (kg/m²):  35
# Diabetes Pedigree Function:  1.4
# Age (years):  40
# 📊 Prediction: Diabetic (Probability = 72.61%)
