# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    classification_report, confusion_matrix,
    accuracy_score, roc_auc_score, roc_curve
)

# Load and preprocess data
columns = ['pregnancies', 'glucose', 'blood_pressure', 'skin_thickness',
           'insulin', 'bmi', 'diabetes_pedigree', 'age', 'outcome']
data = pd.read_csv('pima-indians-diabetes.data', delimiter=',', names=columns, header=None)

# Clean invalid zeros
invalid_zero_cols = ['glucose', 'blood_pressure', 'skin_thickness', 'insulin', 'bmi']
data[invalid_zero_cols] = data[invalid_zero_cols].replace(0, np.nan)
data.fillna(data.median(numeric_only=True), inplace=True)

# Split and scale data
X = data.drop('outcome', axis=1)
y = data['outcome']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# MLP Model
model = MLPClassifier(hidden_layer_sizes=(32, 16, 8), activation='relu',
                      solver='adam', max_iter=1, warm_start=True,
                      early_stopping=False, random_state=42)

# Manual training loop
epochs = 300
train_acc, test_acc = [], []
train_loss = []
classes = np.unique(y_train)

for epoch in range(epochs):
    model.partial_fit(X_train_scaled, y_train, classes=classes)
    y_train_pred = model.predict(X_train_scaled)
    y_test_pred = model.predict(X_test_scaled)
    
    train_acc.append(accuracy_score(y_train, y_train_pred))
    test_acc.append(accuracy_score(y_test, y_test_pred))
    train_loss.append(model.loss_)
    
    print(f"Epoch {epoch+1}/{epochs} - Train Acc: {train_acc[-1]:.4f} - Test Acc: {test_acc[-1]:.4f} - Loss: {train_loss[-1]:.4f}")

# Final predictions
y_pred = model.predict(X_test_scaled)
y_prob = model.predict_proba(X_test_scaled)[:, 1]

# Classification Report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Accuracy and Loss Plot
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_acc, label="Train Accuracy")
plt.plot(test_acc, label="Test Accuracy")
plt.title("Accuracy Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_loss, label="Training Loss", color='orange')
plt.title("Training Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.tight_layout()
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_prob)
auc_score = roc_auc_score(y_test, y_prob)

plt.figure(figsize=(7, 5))
plt.plot(fpr, tpr, label=f"ROC AUC = {auc_score:.2f}")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.show()

# Predict examples
columns = ['pregnancies', 'glucose', 'blood_pressure', 'skin_thickness',
           'insulin', 'bmi', 'diabetes_pedigree', 'age']

# Fix for warning: convert NumPy arrays to DataFrames before scaling
high_risk = pd.DataFrame([[10, 180, 90, 35, 200, 40.0, 1.5, 60]], columns=columns)
low_risk = pd.DataFrame([[1, 85, 60, 20, 80, 22.0, 0.2, 25]], columns=columns)

high_risk_scaled = scaler.transform(high_risk)
low_risk_scaled = scaler.transform(low_risk)

print("\nExample Predictions:")
for i, (person_scaled, label_raw) in enumerate([(high_risk_scaled, "High Risk"), (low_risk_scaled, "Low Risk")], 1):
    pred = model.predict(person_scaled)[0]
    prob = model.predict_proba(person_scaled)[0][1]
    label = "Diabetic" if pred == 1 else "Non-Diabetic"
    print(f"{label_raw} Person: Prediction = {label} (Probability = {prob:.2%})")

# Show predictions for the last 5 entries in the test set
print("\nLast 5 Samples from Test Set with Predictions:")
last_5 = X_test.tail(5)
last_5_scaled = scaler.transform(last_5)

preds = model.predict(last_5_scaled)
probs = model.predict_proba(last_5_scaled)[:, 1]

for i, (input_vals, pred_label, prob_val) in enumerate(zip(last_5.values, preds, probs), 1):
    label = "Diabetic" if pred_label == 1 else "Non-Diabetic"
    print(f"Sample {i}: Features = {input_vals} -> Prediction = {label} (Probability = {prob_val:.2%})")
# Out:
# Epoch 1/100 - Train Acc: 0.6499 - Test Acc: 0.6537 - Loss: 0.6505
# Epoch 96/100 - Train Acc: 0.8250 - Test Acc: 0.7403 - Loss: 0.3646
# Epoch 97/100 - Train Acc: 0.8250 - Test Acc: 0.7446 - Loss: 0.3636
# Epoch 98/100 - Train Acc: 0.8250 - Test Acc: 0.7446 - Loss: 0.3626
# Epoch 99/100 - Train Acc: 0.8250 - Test Acc: 0.7489 - Loss: 0.3616
# Epoch 100/100 - Train Acc: 0.8250 - Test Acc: 0.7489 - Loss: 0.3606
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.79      0.80       151
#            1       0.63      0.68      0.65        80
#
#     accuracy                           0.75       231
#    macro avg       0.72      0.73      0.73       231
# weighted avg       0.75      0.75      0.75       231
# Example Predictions:
# High Risk Person: Prediction = Diabetic (Probability = 89.13%)
# Low Risk Person: Prediction = Non-Diabetic (Probability = 0.24%)
#
# Last 5 Samples from Test Set with Predictions:
# Sample 1: Features = [  0.    119.     72.     29.    125.     32.4     0.141  24.   ] -> Prediction = Non-Diabetic (Probability = 9.19%)
# Sample 2: Features = [  4.    109.     64.     44.     99.     34.8     0.905  26.   ] -> Prediction = Non-Diabetic (Probability = 32.52%)
# Sample 3: Features = [  0.    127.     80.     37.    210.     36.3     0.804  23.   ] -> Prediction = Non-Diabetic (Probability = 41.37%)
# Sample 4: Features = [  6.    105.     70.     32.     68.     30.8     0.122  37.   ] -> Prediction = Non-Diabetic (Probability = 13.15%)
# Sample 5: Features = [ 5.    77.    82.    41.    42.    35.8    0.156 35.   ] -> Prediction = Non-Diabetic (Probability = 2.78%)

# %%
def get_user_input_and_predict(model, scaler):
    print("\n🔢 Enter patient information to predict diabetes:")
    try:
        user_data = {
            'pregnancies': int(input("Pregnancies: ")),
            'glucose': float(input("Glucose level (mg/dL): ")),
            'blood_pressure': float(input("Blood Pressure (mm Hg): ")),
            'skin_thickness': float(input("Skin Thickness (mm): ")),
            'insulin': float(input("Insulin (mu U/ml): ")),
            'bmi': float(input("BMI (kg/m²): ")),
            'diabetes_pedigree': float(input("Diabetes Pedigree Function: ")),
            'age': int(input("Age (years): "))
        }

        # Convert to DataFrame and scale
        input_df = pd.DataFrame([user_data])
        input_scaled = scaler.transform(input_df)

        # Predict
        pred = model.predict(input_scaled)[0]
        prob = model.predict_proba(input_scaled)[0][1]
        label = "Diabetic" if pred == 1 else "Non-Diabetic"

        print(f"\n📊 Prediction: {label} (Probability = {prob:.2%})")

    except ValueError:
        print("⚠️ Invalid input. Please enter numbers only.")

# Call this after training and evaluation
get_user_input_and_predict(model, scaler)
# Out:
# 🔢 Enter patient information to predict diabetes:
# Pregnancies:  0
# Glucose level (mg/dL):  130
# Blood Pressure (mm Hg):  110
# Skin Thickness (mm):  3.5
# Insulin (mu U/ml):  120
# BMI (kg/m²):  35
# Diabetes Pedigree Function:  1.4
# Age (years):  40
# 📊 Prediction: Diabetic (Probability = 72.61%)
